# %%
import pandas as pd

df1 = pd.read_csv("근복_자유게시판_p01-p14_result.csv", encoding= 'utf-8-sig')
df1
# Out:
#      인덱스    글번호                                         제목  작성자         등록일  \
# 0    0.0  378.0         산재 불승인으로 공개요청 드렸는데..처리중이라고만 나와서요..  김혜리  2020-10-19
# 1    1.0  377.0                                     문의드립니다  오윤서  2020-10-19
# 2    2.0  376.0       20년도 마지.막학.기! 보.육.교사자격증 대면→ 비대면으로 전환  백종호  2020-10-16
# 3    3.0  375.0  전국 지자체) 2020년 하반기 봉고 전기차 민간 보급사업 전격 시행(중)  오윤록  2020-10-16
# 4    4.0  374.0                   의정부시 "1인창조기업/중장년 기술창업센터"  박보라  2020-10-16
# ..   ...    ...                                        ...  ...         ...
# 141  NaN    NaN                                        NaN  NaN         NaN
# 142  NaN    NaN                                        NaN  NaN         NaN
# 143  NaN    NaN                                        NaN  NaN         NaN
# 144  NaN    NaN                                        NaN  NaN         NaN
# 145  NaN    NaN                                        NaN  NaN         NaN
#
# ...

# %%
df2 = pd.read_csv("근복_자유게시판_p15-p19_result.csv", encoding= 'utf-8-sig')
df2
# Out:
#      인덱스    글번호                                                 제목  \
# 0    0.0  238.0                                       근로복지공단 이사장님께
# 1    1.0  237.0        보험가입자에게 기생하는 공단 근무 인력을 반으로 줄이시기 강력하게 요구합니다.
# 2    2.0  236.0                                       민원서류 처리 지연..
# 3    3.0  235.0                               현대건설 사기분양, 대법원 확정 판결
# 4    4.0  234.0                                      정말 너무하는거 아닌가요
# 5    5.0  233.0                                           눈물만납니다 2
# 6    6.0  232.0                                   근로복지공단 콜센터 최악...
# 7    7.0  231.0    고용edi 업무이관후 불편사항 [토탈사이트에서 외국인 체류자격확인여부 전산반영 요청]
# 8    8.0  230.0                                          고용산재토탈서비스
# 9    9.0  229.0                         고용산재토탈서비스 외국인근로자체류자격/국적확인!
# 10  10.0  228.0                           집에서 부업 알바 투잡 하실 분 모집합니다!
# 11  11.0  227.0                                  산재 통원치료 불승인 취소 요청
# 12  12.0  226.0                                 근로복지공단 토탈서비스 접속 불가
# ...

# %%
df3 = pd.read_csv("근복_자유게시판_p20~p26_result.csv", encoding= 'utf-8-sig')
df3
# Out:
#     인덱스    글번호                           제목               작성자         등록일  \
# 0   0.0  188.0  건강하고 행복한 워킹맘엔 대디 지원프로그램 리플렛               김효진  2019-09-30
# 1   1.0  187.0            소액체당금 산재보험 적용 사업장               조현숙  2019-09-27
# 2   2.0  186.0        유족 연금 수급에 관하여 말씀 드립니다  KIM LISA HEESOOK  2019-09-26
# 3   3.0  185.0                  인천산재병원 흡연부스               남은정  2019-09-24
# 4   4.0  184.0                         실업급여               작성자  2019-09-24
# ..  ...    ...                          ...               ...         ...
# 74  NaN    NaN                          NaN               NaN         NaN
# 75  NaN    NaN                          NaN               NaN         NaN
# 76  NaN    NaN                          NaN               NaN         NaN
# 77  NaN    NaN                          NaN               NaN         NaN
# 78  NaN    NaN                          NaN               NaN         NaN
#
#       조회수                                                 내용
# ...

# %%
df4 = pd.read_csv("근복_자유게시판_p27~p30_result.csv", encoding= 'utf-8-sig')
df4
# Out:
#      인덱스    글번호                                      제목      작성자         등록일  \
# 0    0.0  118.0                                서류 용도 문의      김윤아  2019-02-19
# 1    1.0  117.0                    현대건설 사기분양, 대법원 확정 판결      김기수  2019-02-13
# 2    2.0  116.0                       건설근로자의재해와현장관리자의태도      조필황  2019-02-11
# 3    3.0  115.0                       폐업장에 고용보험 면제 해주세요      정인철  2019-02-08
# 4    4.0  114.0           의료기관입니다. 재활치료 산정기준에 대해 문의합니다.      김수인  2019-01-29
# 5    5.0  113.0              평택동 일자리안정자금 이전직원분 좀 찾아주세요.  평택동 사업장  2019-01-17
# 6    6.0  112.0                            산재 처리 부탁드려요.      신세정  2019-01-12
# 7    7.0  111.0                                   급여청구앱      김동주  2019-01-07
# 8    8.0  110.0   연구및 학술지 첨부파일 읽기 오류 개선과 최근 연구내용 업로드 요청      김여흠  2019-01-02
# 9    9.0  109.0            1. 산재보험공단 2. 근로복지공사 으로 나눕시다!      이정석  2018-12-26
# 10  10.0  108.0                      2018년 일자리안정자금 주세요.      김미연  2018-12-24
# ...

# %%
df5 = pd.read_csv("근복_자유게시판_29p-p37.csv", encoding= 'utf-8-sig')
df5
# Out:
#     인덱스  글번호                                       제목   작성자         등록일  조회수  \
# 0     0   98                  고용보험 상실 신고서 처리결과가 날라왓는데   최단실  2018-11-13  132
# 1     1   97        실업급여 해당사항 불친절한 통보 및 올바른 정보의 안내 미흡   정소정  2018-11-13  161
# 2     2   96                     현대건설 사기분양, 대법원 확정 판결   김기수  2018-11-07   73
# 3     3   95                            일용근로 임금 과잉 등록   안나리  2018-11-06  113
# 4     4   94                                 부탁 드립니다.   이희영  2018-11-05  103
# ..  ...  ...                                      ...   ...         ...  ...
# 86   86   12    ◆박XX·최XX 꼭 닮은 부처·기관홈피의 자유게시판과 칭찬합시다.◆   최규남  2018-04-19  110
# 87   87   11                              ◆◆ 국가개혁론 ◆◆   최규남  2018-04-19   88
# 88   88   10                 건강보험공단에서 가입자에게 산재신청요구할경우   노동환  2018-04-19   97
# 89   89    9  건설기계조종사의 산재보험 보험가입자 판단 기준 변경 시달관련 문의의 건   김해용  2018-04-19   72
# 90   90    8              [05월 19일 개강] 다중지능상담사2급 자격과정  십대지기  2018-04-19   56
#
# ...

# %%
DF = pd.concat([df1,df2,df3,df4,df5])
DF
# Out:
#      인덱스    글번호                                         제목   작성자         등록일  \
# 0    0.0  378.0         산재 불승인으로 공개요청 드렸는데..처리중이라고만 나와서요..   김혜리  2020-10-19
# 1    1.0  377.0                                     문의드립니다   오윤서  2020-10-19
# 2    2.0  376.0       20년도 마지.막학.기! 보.육.교사자격증 대면→ 비대면으로 전환   백종호  2020-10-16
# 3    3.0  375.0  전국 지자체) 2020년 하반기 봉고 전기차 민간 보급사업 전격 시행(중)   오윤록  2020-10-16
# 4    4.0  374.0                   의정부시 "1인창조기업/중장년 기술창업센터"   박보라  2020-10-16
# ..   ...    ...                                        ...   ...         ...
# 86  86.0   12.0      ◆박XX·최XX 꼭 닮은 부처·기관홈피의 자유게시판과 칭찬합시다.◆   최규남  2018-04-19
# 87  87.0   11.0                                ◆◆ 국가개혁론 ◆◆   최규남  2018-04-19
# 88  88.0   10.0                   건강보험공단에서 가입자에게 산재신청요구할경우   노동환  2018-04-19
# 89  89.0    9.0    건설기계조종사의 산재보험 보험가입자 판단 기준 변경 시달관련 문의의 건   김해용  2018-04-19
# 90  90.0    8.0                [05월 19일 개강] 다중지능상담사2급 자격과정  십대지기  2018-04-19
#
# ...

# %%
del DF['인덱스']

# %%
DF
# Out:
#       글번호                                         제목   작성자         등록일    조회수  \
# 0   378.0         산재 불승인으로 공개요청 드렸는데..처리중이라고만 나와서요..   김혜리  2020-10-19    5.0
# 1   377.0                                     문의드립니다   오윤서  2020-10-19   87.0
# 2   376.0       20년도 마지.막학.기! 보.육.교사자격증 대면→ 비대면으로 전환   백종호  2020-10-16   24.0
# 3   375.0  전국 지자체) 2020년 하반기 봉고 전기차 민간 보급사업 전격 시행(중)   오윤록  2020-10-16   21.0
# 4   374.0                   의정부시 "1인창조기업/중장년 기술창업센터"   박보라  2020-10-16   19.0
# ..    ...                                        ...   ...         ...    ...
# 86   12.0      ◆박XX·최XX 꼭 닮은 부처·기관홈피의 자유게시판과 칭찬합시다.◆   최규남  2018-04-19  110.0
# 87   11.0                                ◆◆ 국가개혁론 ◆◆   최규남  2018-04-19   88.0
# 88   10.0                   건강보험공단에서 가입자에게 산재신청요구할경우   노동환  2018-04-19   97.0
# 89    9.0    건설기계조종사의 산재보험 보험가입자 판단 기준 변경 시달관련 문의의 건   김해용  2018-04-19   72.0
# 90    8.0                [05월 19일 개강] 다중지능상담사2급 자격과정  십대지기  2018-04-19   56.0
#
# ...

# %%
DF.to_csv("근복_자유게시판_all_utf-8-sig.csv", encoding= 'utf-8-sig')

# %%
DF.to_csv("근복_자유게시판_all_cp949.csv", encoding= 'cp949')
