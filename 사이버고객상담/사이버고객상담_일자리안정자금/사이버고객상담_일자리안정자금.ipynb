# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver

from urllib.request import urlopen

from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")

  
    
def scroll_down(driver):
    #driver.execute_script("window.scrollTo(500,document.body.scrollHeight);")
    driver.execute_script("window.scrollBy(0,3000);") # 한페이지 20개씩 출력값
    time.sleep(2)

driver = webdriver.Chrome("C:/temp/chromedriver_240/chromedriver.exe", options= chrome_options)
driver.get('https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20')

url='https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20'


# for i in range(20,953,10):
#     driver.find_element_by_link_text(str(i)).click()
#     time.sleep(1.5)
#     driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()
#     time.sleep(1.5)  

# driver.find_element_by_link_text(str(951)).click()
#   driver.find_element_by_link_text(str(951)).click()


번호 = []
공개여부 = []
제목=[]
등록일 = []
작성자=[]
처리지사=[]
진행현황 = []

내용 = []

답변자 = []
답변내용 = []

#driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(4) ).click()
#time.sleep(3)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(14) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(18) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(22) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(26) ).click()
# time.sleep(10)


for n in range(11,1123):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div.jwxe_root.jwxe_board.pras-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    voice = soup.select('#contents > table > tbody > tr')                     
    
    for i in range(len(voice)):
        no = voice[i].find_all('td')[0].get_text().strip() # 번호
        public = voice[i].find('img').get('alt').strip() # 공개여부 
        title = voice[i].find_all('td')[2].get_text().strip() # 제목
        date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
        writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
        answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
        status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
#         if no=='302':
#             print(no,'글은 삭제되었습니다.')
#             content='삭제된 글'
#             continue
        i

        #scroll_down(driver)
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr:nth-child(%s) > td.tdleft > a'%(i+1)).click()
        

        
        
         
        if public=='공개' and status=='처리완료':
            
            driver.find_element_by_css_selector('''#contents > table > tbody > tr:nth-child(%s) > td.td01 > a'''%(i+1)).click()
#             try:
#                 driver.find_element_by_xpath('''//*[@id="is-cont"]/div[2]/div/div/div[3]/div[2]/div[2]/table/tbody/tr[%s]/td[3]/a'''%(code)).click()
#             except :
#                 continue
            
            time.sleep(2)
            try:
                soup2 = BeautifulSoup(driver.page_source, 'html.parser')#'html.parser')
    
                #content= soup2.find('#contents > table.view02 > tbody > tr:nth-child(1) > td > p').get_text().strip()
                content = soup2.find(id="contents").find('table').find('p').text
                #answer = soup2.find('#contents > table.viewAn > tbody > tr:nth-child(2) > td.td02 > div').get_text().strip()
                answer = soup2.find(id='contents').find('table',{'class':'viewAn'}).find('tbody').find('div').text


            except IndexError:
                continue
            
            except AttributeError:
                print("답글이 작성되지 않았습니다.")
                driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
                continue
    #         except NoSuchElementException:

    #             print(no,"번 글은 삭제된 페이지입니다.")

    #         except TimeoutException:
    #             continue

            else:
                #content = content.replace('\xa0', ' ')
                #answer = answer.replace('')
                
                content = content.replace('\n', ' ')
                answer = answer.replace('\n', ' ')
                answer = answer.replace('\xa0', ' ')
            time.sleep(2)
            driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
        
        else:
            continue
        
        
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.btn_wrap.al_right > a:nth-child(1)').click()
        
        
        

#         if status == '제출':
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[2]/a[1]').click()                                     
#         else:
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[3]/a[1]').click()
        



#         no = voice[i].find_all('td')[0].get_text().strip() # 번호
#         public = voice[i].find_all('td')[1].find('img').get('alt').strip() # 공개여부 
#         title = voice[i].find_all('td')[2].get_text().strip() # 제목
#         date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
#         writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
#         answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
#         status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
        번호.append(no)
        공개여부.append(public)
        제목.append(title)
        등록일.append(date_time)
        작성자.append(writer)
        처리지사.append(answer_name)
        진행현황.append(status)
        내용.append(content)
        


        답변자.append(answer_name)
        답변내용.append(answer)
        #링크.append(str(urlopen(url,a)) )
        
        
        print("=================================================================================================")
        print()
        print('글번호 :',no)
        print("공개여부 :",public)
        print("제목 :",title)
        print("등록일 :", date_time)
        print('작성자 :', writer)       
        print("처리지사 :", answer_name)
        print("진행현황:", status)
        print("내용 :", content)
        print()
        print("답변자 :", answer_name)
        print()
        print("답변내용 :",answer)
        print()
        
        #print(링크)
        print()
        print("=================================================================================================")
        

        time.sleep(2)
        
    print('-----------------------------', n, '페이지 완료 ---------------------------------------------\n')
    #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
    #driver.find_elememnt_by_xpath("//*[@id="contents"]/ul/li[12]/a").click()
    if n % 10 !=0:
        driver.find_element_by_link_text(str(n+1)).click()
        time.sleep(2)
    elif n% 10 == 0:
        #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
        driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()                         
    time.sleep(3)
# Out:
# =================================================================================================
#
# 글번호 : 186708
# 공개여부 : 공개
# 제목 : 직계존비속의 범위
# 등록일 : 2020-11-02
# 작성자 : 최**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 대표자의 처제나 처남은 일자리 안정자금 지원대상이 아닌가요??
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다
국가 등에서 인건비를 재정지원 하는 사업의 경우(기준) 국가 등의 인건비 재정지원은 전액 또는 일부 여부에 관계없이, ‘매년도 시간당 최저임금을 월 소정근로시간 등으로 환산한 금액 이상 지원시’ 인건비 지원으로 간주하여 안정자금 지원 배제합니다. ☞ 인건비 전액 지원 판단 예시     • 월급제 : 매년도 시간당 최저임금액에 월 소정시간을 곱한 금액   * 예시①) 1일 8시간 주5일 근무시 : 최저임금(‘20년 8,590원) × 209시간 = 1,795,310원 이상  * 예시②) 1일 4시간 주5일 근무시 : 최저임금(‘20년 8,590원) ×104시간 = 893,360원 이상  ※ 월 215만원(시간당 10,310원) 이상 인건비 재정지원의 경우는 안정자금 지원대상아님 • 시급제 : 시급으로 판단  * 매년도 시간당 최저임금(‘20년 8,590원) 이상  ▶ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부) 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# ----------------------------- 12 페이지 완료 ---------------------------------------------
#
# =================================================================================================
#
# 글번호 : 186638
# 공개여부 : 공개
# 제목 : 일자리관리번호 어서 확인하나요?
# 등록일 : 2020-10-30
# 작성자 : 홍**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 일자리 안정자금 지원요건 준수 확인서(재검증)을 작성하고 있습니다.  1. 일자리관리번호 어서 확인하나요? 2. 사업자(법인)등록번호는 사업자 번호를 쓰라는 것인지, 법인등록번호를 쓰라는 것인지요? 3. 고용보험관리번호는 사업자번호인가요?
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.1. ▶ 일자리안정자금 지원금 지급내역 조회- 근로복지공단 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 에서 사업장 회원으로 로그인 후 ‘정보조회 → 일자리지원금조회 → 지원금지급내역조회’ 메뉴에서 일자리안정자금 지급내역 조회 / 해당화면에서 일자리관리번호 및 관리번호 등 사업장정보 확인 가능합니다. 2. 법인인 경우 법인등록번호, 개인사업주의 경우 사업자 등록번호로 기준으로 기재하시면 됩니다.3. 고용보험 적용사업장에 `고용보험 관리번호` 가 별도로 부여되며, 사업자 번호와 상이합니다.* 빈 서식이용시 정확한 사업장 정보가 기재되지 않을 경우 누락처리 될 수 있습니다. 가급적 온라인 접수 부탁드립니다. (10월 28일부터 온라인 접수 가능)▶ 지원요건준수확인서 온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청 ⇒ 일자리안정자금지원요건준수확인서일자리안정자금 관련하여 추가적인 문의가 있으실 경우 관할지사 경영복지부로 연락 바랍니다.▶ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부) 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# ----------------------------- 13 페이지 완료 ---------------------------------------------
#
# =================================================================================================
#
# 글번호 : 186623
# 공개여부 : 공개
# 제목 : 직원월급 지원
# 등록일 : 2020-10-29
# 작성자 : 정**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 임대업을하고있고 한명의 관리인을 고용하고있습니다. 일자리안정자금을 신청하려고하는데 예시가 너무 많아서 그런데,어느항목에 신청을 해야하는건가요?
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.일반사업장-고용보험적용근로자용 최초신청서식으로 안내해드리니 참고하시기 바라며, 사업장 업종과 근로자 근무형태 등에 따라 신청서식이 상이하므로 추가적인 내용은 관할지사 경영복지부로 연락 바랍니다.◆ 고용보험 적용근로자 신청서식 (상용, 단시간근로자) [고용보험 기가입자] 2020년 일자리안정자금 지원신청서 + 지원요건확인서[고용보험 신규가입자] 피보험자격 취득신고서 + 일자리안정자금 신청 세부내역 + 지원요건확인서◆ 신청방법 ① 온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청 ⇒ [고용보험기가입자] 2020일자리안정자금지원신청서 / [고용보험 신규가입자] (적용)근로자고용신고 접수② 오프라인접수 ⇒ 일자리안정자금 홈페이지(http://jobfunds.or.kr) ⇒ (상단)신청방법 ⇒ 신청서다운로드 메뉴에서 [고용보험 기가입자] 고용보험 적용 사업장 ⇒ 고용보험 가입 노동자 신청서식 ⇒ 일반사업장 / [고용보험 신규가입자] 고용보험 적용 사업장 ⇒ 고용보험 신규가입 신청서식 ⇒ 노동자 일반사업장용 다운로드 또는 콜센터 통해 팩스/이메일 요청가능⇒ 사업장 관할 근로복지공단 팩스접수 및 우편 또는 방문 접수③ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)▶월평균보수: 지급신청월이 속한 해에 지급하기로 한 보수총액을 해당 근무개월수로 나눈 금액▶주소정근로시간 : 근로자와 사용자간 근로하기로 미리 정한 시간(주 근무일수×일 소정근로시간)을 기재▶정액급여: 소정근로시간에 대해 정기적․고정적으로 지급받기로 한 보수의 합계▶ 최저임금 검증시에는 신청서에 기재된 정액급여를 소정근로시간으로 나눈 시간급 임금이 8,590원 이상 10.310원이하 이면 최저 임금 준수 인정(시간급으로 판단) 입니다.* 월급근로자 = 월정액급여/월소정근로시간, 주급근로자 = 주정액급여/주소정근로시간, 시간급근로자 = 시간급 임금 ※ 신청일 현재 고용보험 피보험자수가 5인 미만 일 경우 오프라인 신청 가능※ 공동대표자가 있는 경우 “공동대표자 개인정보활용동의서”별도 제출필요 ※ 2020년 일자리안정자금 신규 및 추가근로자 신청시기:  ’20.12.14.(월) 까지 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# =================================================================================================
#
# 글번호 : 186619
# 공개여부 : 공개
# 제목 : 일자리 안정자금 대상자 변경
# 등록일 : 2020-10-29
# 작성자 : 박**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 안녕하세요.   저희회사에 일자리 안정자금을 지원받는 근로자가 1명있는데  급여가 인상되어 지원 대상이 안되게 되었습니다. 지원대상자를 삭제 하려고 하는데 전화연결이 잘 안되서 온라인으로 문의드립니다. 변경 방법을 알려주세요.  감사합니다.
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.월보수 215만원은 당해연도 매월 지급되는 보수를 '월평균 한' 개념으로 일시적 사유로 일부 월의 임금이 215만원을 초과하였다 하더라도 반드시 변경신고를 하여야 하는 것은 아닙니다. 다만, 지원기간 도중 임금협상 등을 통해 기본급 인상 등 월평균 보수가 215만원이 넘을 것이 명확한 경우에는 반드시 변경신고를 하여야 합니다. 변경신고를 하지 않을 경우 다음연도 확정 신고된 보수총액 일괄 모니터링을 통해 사후 환수될 수 있음에 유의하시기 바랍니다.-’21년도에 신고한 ’20년분 확정 보수총액을 토대로 산정된 월평균보수가 215만원의 110% 수준인 237만원을 초과한 경우, 지원요건을 갖추지못한 것으로 간주하고 해당 근로자에 대한 지원금은 전액 환수○ 신청서식 : 일자리 안정자금 상용근로자 변경신고서○ 온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청○ 오프라인접수 ⇒ 일자리안정자금 홈페이지(http://jobfunds.or.kr) ⇒ (상단)신청방법 ⇒ 신청서다운로드 메뉴에서 다운로드 또는 콜센터 통해 팩스/이메일 요청가능⇒ 사업장 관할 근로복지공단 팩스접수 및 우편 또는 방문 접수○ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)* (유의사항) 월평균보수, 주소정근로시간이 변경되었음에도 불구하고 변경신고를 하지 않은 경우, 향후 고용보험 보수총액 신고사항 등과 비교하여 과오지급된 지원금이 환수될 수 있음만일, 지원금을 지급 받던 중 ｢고용·산재보험 월평균 보수변경신고서｣에 따라 월평균보수 변경신고를 하였다 하더라도 이는 안정자금 지원기준인 월평균보수 변경과는 무관하기 때문에 반드시 위 변경신고서에 따라 신고해야 함기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# =================================================================================================
#
# 글번호 : 186609
# 공개여부 : 공개
# 제목 : 지원요건 준수확인서 미제출 통지문자
# 등록일 : 2020-10-29
# 작성자 : 조**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 10월 21일에 우체국을 통해서 근로복지공단 유성지사에 등기우편물 (등기번호  1300_3126_41853) 로 지원요건 준수확인서를 제출했습니다. 10월 28일자로 근로복지공단에서 일자리안정자금 재검증확인서를 제출하지 않아서 11월 지원금이 지급되지 않을 예정이라는 문자를 받았습니다. 이와 관련하여 현재 상황을 확인하고 싶습니다.
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.* 지원요건준수확인서가 접수가 되었더라도 아직 미확인(승인 전) 사업장에 대해 부득이하게 문자가 발송 될 수 있는 점 양해 부탁드리며, 접수가 되었다면 확인 절차를 거쳐 이상이 없을 경우, 지원금 계속 지원이 될 예정입니다.서식접수 현황에 대해서는 정보 확인 및 전산 확인이 필요하여 답변이 어려운 점 양해부탁드리며, 번거로우시겠지만 [ 사업자등록번호 or 고용관리번호 / 사업장명 ] 을 같이 기재하여 재문의 주시거나, 실제 업무를 담당하고 있는 관할지사 담당자를 통해 확인 바랍니다.불편드려 정말 죄송합니다.▶ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# -----------------------------
온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청 ⇒ [고용보험기가입자] 2020일자리안정자금지원신청서 ○ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)※ 공동대표자가 있는 경우 “공동대표자 개인정보활용동의서”별도 제출필요 ※ 사업장 업종과 근로자 근무형태 등에 따라 신청서식이 상이하므로 추가적인 내용은 관할지사 경영복지부로 연락 바랍니다.기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# =================================================================================================
#
# 글번호 : 183576
# 공개여부 : 공개
# 제목 : 안정자금이 4만원이 맞나요?
# 등록일 : 2020-09-03
# 작성자 : 김**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 통장에 4만원이 일자리안정자금이라는 이름으로 입금되었습니다.  더 되는 것으로 알고 있는데, 제대로 신청된 것이 맞는지 확인 부탁드립니다^^  애써주셔서 감사합니다^^
#
# 답변자 : 콜센터
#
# 답변내용 : 고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.지원내역에 대해서는 정보 확인 및 전산 확인이 필요하여 답변이 어려운 점 양해부탁드리며, 번거로우시겠지만 [ 사업자등록번호 or 고용관리번호 / 사업장명 ] 을 같이 기재하여 재문의 주시거나, 온라인경로를 통해서 확인 바랍니다.▶ 일자리안정자금 지원금 지급내역 조회- 근로복지공단 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 에서 사업장 회원으로 로그인 후 ‘정보조회 → 일자리지원금조회 → 지원금지급내역조회’ 메뉴에서 일자리안정자금 지급내역 조회 후 ◎사업장지원정보의 ‘지원월’ 을 한번 더 선택하게 되면 해당 월 근로자상세내역 확인이 가능합니다.  관련하여 추가적인 문의가 있으실 경우 실제 업무를 담당하고 있는 관할지사 담당자를 통해 확인 바랍니다.○ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# =================================================================================================
#
# 글번호 : 183566
# 공개여부 : 공개
# 제목 : 일자리안정자금과 두루누리지원금
# 등록일 : 2020-09-03
# 작성자 : 나**
# 처리지사 : 콜센터1
# 진행현황: 처리완료
# 내용 : 9/1(화) 문의글을 올렸는데 콜센터1(으)로 이관 이라는 문자를 받았습니다.  9/2(수) 인터넷질문 답변등록완료. 라고 문자가왔는데 따로 콜센터에서 연락온적이 없습니다.   기존대로 답변글로 알려주세요!!  질문드린것을 요약하자면, 일자리안정자금과 두루누리지원금을 지원받고 있는데  주식으로 인한 배당금은 급여소득으로 보고 있다고 하셨는데,   주식매도시 수익분도 급여소득으로 보는지,  일자리 안정자금과 두루누리지원금 "215만원 이하"에 주식매도수익분도 포함하여 215만원인지 알고싶습니다.  (참고로 미국-해외주식입니다)  제 개인적인 일로 회사에 누를끼치면 안되는거라 빨리 답변을  주셨으면 합니다. 빠른 답변 기다리겠습니다.감사합니다.
#
# 답변자 : 콜센터1
#
# 답변내용 : 고객님 안녕하십니까? 근로복지공단 콜센터입니다. 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다. 사이버상담실은 일반적인 기준 사항에 대해서 상담 드리는 기관으로서 개별 사업장의 구체적인 사실관계 조사 및 관련서류 검토가 필요하며, 이러한 확인 및 검토 업무는 사업장 관할 우리 공단에서 직접 수행함에 따라 사이버상담실은 이에 대한 직접적인 최종 판단까지는 내려드릴 수 없음을 양해해 주시기 바랍니다. 고객님께서 문의주신 내용에 대한 답변 드립니다. 일지리 안정자금과 두루누리지원금의 월평균보수215만원 미만인 근로자보험지원의 제하늘 제한하는 근로자의 재산 및 종합소득 등의 고시기준
온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청 ⇒ [고용보험기가입자] 2020일자리안정자금지원신청서 / [고용보험 신규가입자] (적용)근로자고용신고 접수② 오프라인접수 ⇒ 일자리안정자금 홈페이지(http://jobfunds.or.kr) ⇒ (상단)신청방법 ⇒ 신청서다운로드 메뉴에서 [고용보험 기가입자] 고용보험 적용 사업장 ⇒ 고용보험 가입 노동자 신청서식 ⇒ 일반사업장 / [고용보험 신규가입자] 고용보험 적용 사업장 ⇒ 고용보험 신규가입 신청서식 ⇒ 노동자 일반사업장용 다운로드 또는 콜센터 통해 팩스/이메일 요청가능⇒ 사업장 관할 근로복지공단 팩스접수 및 우편 또는 방문 접수③ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)※ 신청일 현재 고용보험 피보험자수가 5인 미만 일 경우 오프라인 신청 가능※ 사업장 업종과 근로자 근무형태 등에 따라 신청서식이 상이하므로 추가적인 내용은 관할지사 경영복지부로 연락 바랍니다.▶ 일자리안정자금 지원금 지급내역 조회 (지원근로자 조회)- 근로복지공단 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 에서 사업장 회원으로 로그인 후 ‘정보조회 → 일자리지원금조회 → 지원금지급내역조회’ 메뉴에서 일자리안정자금 지급내역 조회 후 ◎사업장지원정보의 ‘지원월’ 을 한번 더 선택하게 되면 해당 월 근로자상세내역 확인이 가능합니다.  기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# =================================================================================================
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-1-3bb8959d424e> in <module>
#     126                 answer = answer.replace('\xa0', ' ')
#     127             time.sleep(2)
# --> 128             driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
#     129
#     130         else:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\.conda\envs\cslee3.7\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\.conda\envs\cslee3.7\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\.conda\envs\cslee3.7\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: headless chrome=86.0.4240.183)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.18363 x86_64)

# %%
import pandas as pd

df3 = pd.DataFrame(columns= ['글번호','공개여부','제목','등록일','작성자','처리지사','진행현황', '내용', '답변자', '답변내용'])





df3['글번호'] = 번호
df3['공개여부']= 공개여부
df3['제목'] = 제목
df3['등록일'] = 등록일
df3['작성자'] = 작성자
df3['처리지사'] = 처리지사
df3['진행현황'] = 진행현황
df3['내용'] = 내용
df3['답변자'] = 답변자
df3['답변내용'] = 답변내용

df3   
    
    

#         번호.append(no)
#         제목.append(title)
#         작성자.append(writer)
#         등록일.append(date_time)
#         진행현황.append(status)
#         내용.append(content)
# Out:
#         글번호 공개여부                       제목         등록일  작성자 처리지사  진행현황  \
# 0    186708   공개                직계존비속의 범위  2020-11-02  최**  콜센터  처리완료
# 1    186695   공개                 일자리안정지원금  2020-11-02  최**  콜센터  처리완료
# 2    186694   공개                  일자리안전자금  2020-11-01  허**  콜센터  처리완료
# 3    186678   공개  일자리 안정자금 반환금 독촉 안내문 ...  2020-10-31  홍**  콜센터  처리완료
# 4    186665   공개  일자리 안정자금 가입되어 있는지 확인...  2020-10-30  오**  콜센터  처리완료
# ..      ...  ...                      ...         ...  ...  ...   ...
# 218  183560   공개              코로나 관련 매장휴간  2020-09-03  조**  콜센터  처리완료
# 219  183533   공개               일자리안정자금 관련  2020-09-02  임**  콜센터  처리완료
# 220  183529   공개            고용유지지원금 관련 문의  2020-09-02  정**  콜센터  처리완료
# 221  183520   공개               고용장려금 상담신청  2020-09-02  김**  콜센터  처리완료
# 222  183482   공개          기존에 안정자금 받고 있었고  2020-09-02  서**  콜센터  처리완료
#
#                                                     내용  답변자  \
# 0                   대표자의 처제나 처남은 일자리 안정자금 지원대상이 아닌가요??  콜센터
# 1    남편이 집을 나가고 지금은 이혼한 상태입니다 코로나로 일자리도 없고 이혼후 돈도 한...  콜센터
# 2                              코로나19 때문에 실직중 그래서 신청합니다  콜센터
# 3    안녕하세요 문의드립니다. 우편으로 받았는데요. 회사가 아닌 집으로 왔구요.  성림종...  콜센터
# 4    1. 일자리 안정자금신청을 팩스로 접수하였습니다.  2. 가입여부를 확인하고 싶습니...  콜센터
# ..                                                 ...  ...
# 218  뷔페에서근무중인 27살 직원입니다. 불가피하게 정부에서 임시 휴업하라는 명령때문에 ...  콜센터
# 219  안녕하세요, 법인 사업장 총무부 사원입니다. 8월1일에 새로운 직원이 입사하여 8월...  콜센터
# 220  안녕하세요, 8월 27일까지 코로나19로 인한 고용유지지원금을 지원받은 업장 담당자...  콜센터
# 221  저희는 2020년 5월 7일 어르신주간보호센터와 방문목욕, 방문요양센터를 개설환 기...  콜센터
# 222  9월에 또 신청을 해야하는데 그전에 누구가 신청 되어 있는지와 9월에 신청하는 방법...  콜센터
#
#                                                   답변내용
# 0    고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 1    고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 2    고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 3    고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 4    고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# ..                                                 ...
# 218  고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 219  고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 220  고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 221  고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
# 222  고객님 안녕하십니까?근로복지공단 콜센터입니다.먼저 근로복지공단에 대한 고객님의 관심...
#
# [223 rows x 10 columns]

# %%
import pandas as pd

df2 = pd.DataFrame(columns= ['글번호','공개여부','제목','등록일','작성자','처리지사','진행현황', '내용', '답변자', '답변내용'])





df2['글번호'] = 번호
df2['공개여부']= 공개여부
df2['제목'] = 제목
df2['등록일'] = 등록일
df2['작성자'] = 작성자
df2['처리지사'] = 처리지사
df2['진행현황'] = 진행현황
df2['내용'] = 내용
df2['답변자'] = 답변자
df2['답변내용'] = 답변내용

df2   
    
    

#         번호.append(no)
#         제목.append(title)
#         작성자.append(writer)
#         등록일.append(date_time)
#         진행현황.append(status)
#         내용.append(content)

# %%
df3.to_csv("사이버 고객상담 일자리안정자금_109까지(utf-8-sig)_result.csv", encoding= 'utf-8-sig')

# %%
df3.to_csv("사이버 고객상담 일자리안정자금_109까지(cp949)_result.csv", encoding= 'cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-6-24035c4e4726> in <module>
# ----> 1 df3.to_csv("사이버 고객상담 일자리안정자금_109까지(cp949)_result.csv", encoding= 'cp949')
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     326                 break
#     327
# --> 328             self._save_chunk(start_i, end_i)
#     329
#     330     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     360         )
#     361
# --> 362         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'cp949' codec can't encode character '\uff65' in position 951: illegal multibyte sequence
