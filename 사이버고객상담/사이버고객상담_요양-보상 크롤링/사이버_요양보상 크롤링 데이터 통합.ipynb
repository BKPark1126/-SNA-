# %%
import pandas as pd 

df = pd.read_csv("data/사이버 고객상담 요양보상_168까지_(utf-8-sig)_result.csv")
df
# Out:
#      Unnamed: 0     글번호 공개여부                       제목         등록일  작성자 처리지사  \
# 0             0  185198   공개  휴업급여 신청 시점 문의 / 의사 소...  2020-09-29  지**  콜센터
# 1             1  185190   공개           휴직으로 인한 퇴직금 문의  2020-09-29  임**  콜센터
# 2             2  185144   공개                   추가상병신청  2020-09-28  윤**  콜센터
# 3             3  185142   공개                   자문의 소견  2020-09-28  박**  콜센터
# 4             4  185057   공개  2017월 6월 자전거로 출근중 사고...  2020-09-26  배**  콜센터
# ..          ...     ...  ...                      ...         ...  ...  ...
# 236         236  162681   공개  저희어머니가 회사에서 일하다 다쳤습니...  2019-06-06  김**  콜센터
# 237         237  162623   공개                   요양비 청구  2019-06-03  이**  콜센터
# 238         238  162621   공개             진료비 및 약제비 청구  2019-06-03  이**  콜센터
# 239         239  162601   공개                  산재 휴업급여  2019-06-03  장**  콜센터
# 240         240  162600   공개                     요양급여  2019-06-03  장**  콜센터
#
# ...

# %%
df2 = pd.read_csv("data/사이버 고객상담 요양보상_169부터_301까지_(utf-8-sig)_result.csv")
df2
# Out:
#      Unnamed: 0     글번호 공개여부                       제목         등록일  작성자  처리지사  \
# 0             0  162575   공개                    산재승인시  2019-05-31  김**   콜센터
# 1             1  162556   공개  직계가족 산재처리 가능여부에 대해서 ...  2019-05-31  김**   콜센터
# 2             2  162550   공개  제발, 유족연금 지급하지 말아주세요~...  2019-05-31  김**   콜센터
# 3             3  162505   공개                     산재신청  2019-05-29  백**   콜센터
# 4             4  162494   공개      건설업 준공 후 산재처리 관련 문의  2019-05-29  김**   콜센터
# ..          ...     ...  ...                      ...         ...  ...   ...
# 230         230  151265   공개          산재기간중 휴업급여에 대하여  2018-02-03  이**   콜센터
# 231         231  150843   공개             산재보험 적용여부 문의  2018-01-25  박**   콜센터
# 232         232  150835   공개  근무 이틀째에 손가락을 다쳤는데 산재...  2018-01-24  박**   콜센터
# 233         233  150820   공개        이번1월4일 통원종류 환자인데요  2018-01-24  원**  콜센터1
# 234         234  150696   공개          산재보험 지급 및 요율 문의  2018-01-19  박**   콜센터
#
# ...

# %%
df3 = pd.read_csv("data/사이버 고객상담 요양보상_302부터_323까지_(utf-8-sig)_result.csv")
df3
# Out:
#     Unnamed: 0     글번호 공개여부                       제목         등록일  작성자  \
# 0            0  150651   공개          출퇴근 중 발생한 사고 문의  2018-01-18  이**
# 1            1  150649   공개  진료계획서 원본여부 다시 질의합니다....  2018-01-18  이**
# 2            2  150547   공개           재요양신청 광주근로복지공단  2018-01-15  김**
# 3            3  150545   공개  한국야구르트 배달원(일명 야구르트 아...  2018-01-15  최**
# 4            4  150507   공개      퇴직 후에도 산재 처리가 가능한가요  2018-01-15  박**
# 5            5  150498   공개                     공단측에  2018-01-14  김**
# 6            6  150491   공개  사고로 새끼손가락 수술후에도 가슴통증...  2018-01-14  김**
# 7            7  150432   공개  장비보험 처리시 산재보험 처리가능여부...  2018-01-12  김**
# 8            8  150310   공개        진료계획서 원본여부 확인해주세요  2018-01-09  이**
# 9            9  150272   공개                휠체어 대여 문의  2018-01-08  장**
# 10          10  150167   공개         [출퇴근 산재 관련 질의응답]  2018-01-04  문**
# 11          11  149996   공개      산재의 책임은 어떻게 되는지요...  2017-12-31  오**
# ...

# %%
df4 = pd.read_csv("data/사이버 고객상담 요양보상_324부터 끝까지_(utf-8-sig)_result.csv",encoding='euc-kr')
df4
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-28fff759edab> in <module>
# ----> 1 df4 = pd.read_csv("data/사이버 고객상담 요양보상_324부터 끝까지_(utf-8-sig)_result.csv",encoding='euc-kr')
#       2 df4
#
# ...
