# %%
import pandas as pd 

df1 = pd.read_csv("사이버 고객상담 기타_all(utf-8-sig).csv", encoding='utf-8-sig')
df1
# Out:
#          글번호 공개여부                       제목         등록일  작성자      처리지사  진행현황  \
# 0     186118   공개         외국국적 직원 채용 관련 문의  2020-10-23  오**       콜센터  처리완료
# 1     186104   공개          관할지역 팩스번호 안내 요청  2020-10-22  이**       콜센터  처리완료
# 2     186103   공개  퇴사날짜 정정신고 가능한지 알고 싶습...  2020-10-22  최**       콜센터  처리완료
# 3     186068   공개  저소득 장기실업자 생활안정자금 문의입...  2020-10-22  김**       콜센터  처리완료
# 4     185995   공개                 실업급여신청관계  2020-10-21  권**       콜센터  처리완료
# ...      ...  ...                      ...         ...  ...       ...   ...
# 1957  144051   공개                  문의드립니다.  2015-11-10  오**  광주고객지원센터  처리완료
# 1958  144042   공개  산재,고용보험 성립(가입) 신고안내서...  2015-11-09  조**  광주고객지원센터  처리완료
# 1959  144039   공개       근로내용 확인신고서 작성 문의사항  2015-11-09  김**  광주고객지원센터  처리완료
# 1960  144037   공개               고용보험지원금 문의  2015-11-09  신**  광주고객지원센터  처리완료
# 1961  144017   공개             후유 증상 서비스 카드  2015-11-04  한**  광주고객지원센터  처리완료
#
# ...

# %%
df1.to_csv('사이버 고객상담 기타_all(cp949).csv',encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-125-6fdea2155f61> in <module>
# ----> 1 df1.to_csv('사이버 고객상담 기타_all(cp949).csv',encoding='cp949')
#
# ~\AppData\Local\conda\conda\envs\kyu3.7\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\AppData\Local\conda\conda\envs\kyu3.7\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ...

# %%
df= df1[['글번호','공개여부','제목','등록일','작성자','처리지사','진행현황','내용', '답변자','답변내용']].copy()
df
# Out:
#          글번호 공개여부                       제목         등록일  작성자      처리지사  진행현황  \
# 0     186118   공개         외국국적 직원 채용 관련 문의  2020-10-23  오**       콜센터  처리완료
# 1     186104   공개          관할지역 팩스번호 안내 요청  2020-10-22  이**       콜센터  처리완료
# 2     186103   공개  퇴사날짜 정정신고 가능한지 알고 싶습...  2020-10-22  최**       콜센터  처리완료
# 3     186068   공개  저소득 장기실업자 생활안정자금 문의입...  2020-10-22  김**       콜센터  처리완료
# 4     185995   공개                 실업급여신청관계  2020-10-21  권**       콜센터  처리완료
# ...      ...  ...                      ...         ...  ...       ...   ...
# 1957  144051   공개                  문의드립니다.  2015-11-10  오**  광주고객지원센터  처리완료
# 1958  144042   공개  산재,고용보험 성립(가입) 신고안내서...  2015-11-09  조**  광주고객지원센터  처리완료
# 1959  144039   공개       근로내용 확인신고서 작성 문의사항  2015-11-09  김**  광주고객지원센터  처리완료
# 1960  144037   공개               고용보험지원금 문의  2015-11-09  신**  광주고객지원센터  처리완료
# 1961  144017   공개             후유 증상 서비스 카드  2015-11-04  한**  광주고객지원센터  처리완료
#
# ...

# %%
글번호 =[]
공개여부 =[]
제목 = []
등록일= []
처리지사 = []
진행현황 = []
내용 =[]
답변자 =[]
답변내용 = []

for i in df['글번호']:
#     i = i.replace("\u2024", "")
#     i = i.replace("\u30fb", "")
#     i = i.replace("\u21e8", "")
#     i = i.replace("\u2013", "")
#     i = i.replace("\uff62", "")
#     i = i.replace("\uff63", "")
#     i = i.replace("\U000f02ef", "")
    글번호.append(i)
    

for i in df['공개여부']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")
    i = i.replace('\u2780', "")
    i = i.replace("\u2781", "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f7', "")
    
    
    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473' , "")
    i = i.replace('\u24f5', "")
    
    공개여부.append(i)
    

for i in df['제목']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")
    i = i.replace('\u2780', "")
    i = i.replace('\u2781', "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f7', "")
    
    
    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473' , "")
    i = i.replace('\u24f5', "")
    
    제목.append(i)

for i in df['등록일']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")    
    i = i.replace('\u2780', "")
    i = i.replace('\u2781', "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")              
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f7', "")
    
    
    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473' , "")
    i = i.replace('\u24f5', "")
    
    등록일.append(i)

for i in df['처리지사']:
#     i = i.replace("\u2024", "")
#     i = i.replace("\u30fb", "")
#     i = i.replace("\u21e8", "")
#     i = i.replace("\u2013", "")
#     i = i.replace("\uff62", "")
#     i = i.replace("\uff63", "")
#     i = i.replace("\U000f02ef", "")
#    i = i.replace("\u2219", "")
    처리지사.append(i)

for i in df['진행현황']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")    
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")
    i = i.replace('\u2780', "")
    i = i.replace('\u2781', "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f7', "")
    
    
    
    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473' , "")
    i = i.replace('\u24f5', "")
    
    진행현황.append(i)

for i in df['내용']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")
    i = i.replace("\u2219", "")
    i = i.replace('\u2781', "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")           
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f7', "")
    

    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473' , "")
    i = i.replace('\u24f5', "")
    
    내용.append(i)
    
    
    


for i in df['답변자']:
#     i = i.replace("\u2024", "")
#     i = i.replace("\u30fb", "")
#     i = i.replace("\u21e8", "")
#     i = i.replace("\u2013", "")
#     i = i.replace("\uff62", "")
#     i = i.replace("\uff63", "")
#     i = i.replace("\U000f02ef", "")
    답변자.append(i)

for i in df['답변내용']:
    i = i.replace("\u2024", "")
    i = i.replace("\u30fb", "")
    i = i.replace("\u21e8", "")
    i = i.replace("\u2013", "")
    i = i.replace("\uff62", "")
    i = i.replace("\uff63", "")
    i = i.replace("\U000f02ef", "")
    i = i.replace("\u2219", "")
    i = i.replace("\u2027", "")
    i = i.replace("\u27e1", "")
    i = i.replace('\uf000', "")
    i = i.replace('\u2780', "")
    i = i.replace('\u2781', "")
    i = i.replace('\u2782', "")
    i = i.replace('\u2611', "")                  
    i = i.replace('\u231c', "")
    i = i.replace('\u231f', "")
    i = i.replace('\xa0' , "")
    i = i.replace('\u24f5', "")
    
    
    
    i = i.replace('\u25ba' , "")              
    i = i.replace('\u21e8', "")
    i = i.replace('\u246f', "")
    i = i.replace('\u2473', "")
    i = i.replace('\u24f5', "")
    
    
    답변내용.append(i)

# %%
df_result = df.copy()
df_result['글번호']= 글번호
df_result['공개여부'] = 공개여부
df_result['제목']= 제목
df_result['등록일'] = 등록일
df_result['처리지사'] = 처리지사
df_result['진행현황'] = 진행현황
df_result['내용'] = 내용
df_result['답변자'] = 답변자
df_result['답변내용'] = 답변내용
df_result
# Out:
#          글번호 공개여부                       제목         등록일  작성자      처리지사  진행현황  \
# 0     186118   공개         외국국적 직원 채용 관련 문의  2020-10-23  오**       콜센터  처리완료
# 1     186104   공개          관할지역 팩스번호 안내 요청  2020-10-22  이**       콜센터  처리완료
# 2     186103   공개  퇴사날짜 정정신고 가능한지 알고 싶습...  2020-10-22  최**       콜센터  처리완료
# 3     186068   공개  저소득 장기실업자 생활안정자금 문의입...  2020-10-22  김**       콜센터  처리완료
# 4     185995   공개                 실업급여신청관계  2020-10-21  권**       콜센터  처리완료
# ...      ...  ...                      ...         ...  ...       ...   ...
# 1957  144051   공개                  문의드립니다.  2015-11-10  오**  광주고객지원센터  처리완료
# 1958  144042   공개  산재,고용보험 성립(가입) 신고안내서...  2015-11-09  조**  광주고객지원센터  처리완료
# 1959  144039   공개       근로내용 확인신고서 작성 문의사항  2015-11-09  김**  광주고객지원센터  처리완료
# 1960  144037   공개               고용보험지원금 문의  2015-11-09  신**  광주고객지원센터  처리완료
# 1961  144017   공개             후유 증상 서비스 카드  2015-11-04  한**  광주고객지원센터  처리완료
#
# ...

# %%
df_result.to_csv("사이버고객상담_기타_result(cp949).csv",encoding='cp949',index= False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-129-6c1a94ecdb09> in <module>
# ----> 1 df_result.to_csv("사이버고객상담_기타_result(cp949).csv",encoding='cp949',index= False)
#
# ~\AppData\Local\conda\conda\envs\kyu3.7\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\AppData\Local\conda\conda\envs\kyu3.7\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ...

# %%
len(내용)
# Out:
# 0
