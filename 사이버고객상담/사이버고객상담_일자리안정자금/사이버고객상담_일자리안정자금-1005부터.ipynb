# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver

from urllib.request import urlopen

from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")

  
    
def scroll_down(driver):
    #driver.execute_script("window.scrollTo(500,document.body.scrollHeight);")
    driver.execute_script("window.scrollBy(0,3000);") # 한페이지 20개씩 출력값
    time.sleep(2)

driver = webdriver.Chrome("C:/temp/chromedriver_240/chromedriver.exe", options= chrome_options)
driver.get('https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20')

url='https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20'


for i in range(20,1005,10):
    driver.find_element_by_link_text(str(i)).click()
    time.sleep(1.5)
    driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()
    time.sleep(1.5)  

driver.find_element_by_link_text(str(1005)).click()
#   driver.find_element_by_link_text(str(951)).click()


번호 = []
공개여부 = []
제목=[]
등록일 = []
작성자=[]
처리지사=[]
진행현황 = []

내용 = []

답변자 = []
답변내용 = []

#driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(4) ).click()
#time.sleep(3)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(14) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(18) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(22) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(26) ).click()
# time.sleep(10)


for n in range(1005,1123):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div.jwxe_root.jwxe_board.pras-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    voice = soup.select('#contents > table > tbody > tr')                     
    
    for i in range(len(voice)):
        no = voice[i].find_all('td')[0].get_text().strip() # 번호
        public = voice[i].find('img').get('alt').strip() # 공개여부 
        title = voice[i].find_all('td')[2].get_text().strip() # 제목
        date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
        writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
        answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
        status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
#         if no=='302':
#             print(no,'글은 삭제되었습니다.')
#             content='삭제된 글'
#             continue
        i

        #scroll_down(driver)
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr:nth-child(%s) > td.tdleft > a'%(i+1)).click()
        

        
        
         
        if public=='공개' and status=='처리완료':
            
            driver.find_element_by_css_selector('''#contents > table > tbody > tr:nth-child(%s) > td.td01 > a'''%(i+1)).click()
#             try:
#                 driver.find_element_by_xpath('''//*[@id="is-cont"]/div[2]/div/div/div[3]/div[2]/div[2]/table/tbody/tr[%s]/td[3]/a'''%(code)).click()
#             except :
#                 continue
            
            time.sleep(2)
            try:
                soup2 = BeautifulSoup(driver.page_source, 'html.parser')#'html.parser')
    
                #content= soup2.find('#contents > table.view02 > tbody > tr:nth-child(1) > td > p').get_text().strip()
                content = soup2.find(id="contents").find('table').find('p').text
                #answer = soup2.find('#contents > table.viewAn > tbody > tr:nth-child(2) > td.td02 > div').get_text().strip()
                answer = soup2.find(id='contents').find('table',{'class':'viewAn'}).find('tbody').find('div').text


            except IndexError:
                continue
            
            except AttributeError:
                print("답글이 작성되지 않았습니다.")
                driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
                continue
    #         except NoSuchElementException:

    #             print(no,"번 글은 삭제된 페이지입니다.")

    #         except TimeoutException:
    #             continue

            else:
                #content = content.replace('\xa0', ' ')
                #answer = answer.replace('')
                
                content = content.replace('\n', ' ')
                answer = answer.replace('\n', ' ')
                answer = answer.replace('\xa0', ' ')
            time.sleep(2)
            driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
        
        else:
            continue
        
        
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.btn_wrap.al_right > a:nth-child(1)').click()
        
        
        

#         if status == '제출':
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[2]/a[1]').click()                                     
#         else:
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[3]/a[1]').click()
        



#         no = voice[i].find_all('td')[0].get_text().strip() # 번호
#         public = voice[i].find_all('td')[1].find('img').get('alt').strip() # 공개여부 
#         title = voice[i].find_all('td')[2].get_text().strip() # 제목
#         date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
#         writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
#         answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
#         status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
        번호.append(no)
        공개여부.append(public)
        제목.append(title)
        등록일.append(date_time)
        작성자.append(writer)
        처리지사.append(answer_name)
        진행현황.append(status)
        내용.append(content)
        


        답변자.append(answer_name)
        답변내용.append(answer)
        #링크.append(str(urlopen(url,a)) )
        
        
        print("=================================================================================================")
        print()
        print('글번호 :',no)
        print("공개여부 :",public)
        print("제목 :",title)
        print("등록일 :", date_time)
        print('작성자 :', writer)       
        print("처리지사 :", answer_name)
        print("진행현황:", status)
        print("내용 :", content)
        print()
        print("답변자 :", answer_name)
        print()
        print("답변내용 :",answer)
        print()
        
        #print(링크)
        print()
        print("=================================================================================================")
        

        time.sleep(2)
        
    print('-----------------------------', n, '페이지 완료 ---------------------------------------------\n')
    #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
    #driver.find_elememnt_by_xpath("//*[@id="contents"]/ul/li[12]/a").click()
    if n % 10 !=0:
        driver.find_element_by_link_text(str(n+1)).click()
        time.sleep(2)
    elif n% 10 == 0:
        #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
        driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()                         
    time.sleep(3)
# Out:
# ...
#
# 글번호 : 155578
# 공개여부 : 공개
# 제목 : 내년 일자리 안정자금 지급 관련
# 등록일 : 2018-09-04
# 작성자 : 임**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 상가 건물 관리사무소 경비 위생원 직원에 대하여 현재 일자리 안정자금을 지급받고 있습니다. 문의사항은 내년에도 지급한다고 하는데 문제는 상가운영에 어려움이 많아 인원 축소 이야기가 있는데 이런경우 인원 축소가 발생한 경우 일자리 안정자금 지원에서 전년도 직원 비율에 따라 불가한지 문의드립니다. 물론 직원의 급여수준과 근무시간표 등 일자리 안정자금 기준에 적합한 경우에 한하는 것은 아는데 혹여 내년도 직원 축소로 인하여 전체 근로자 기준 비율이나 다른 조건으로 미지급 상황이 생기는 것인지 알아야 상부에 보고할 수 있을 거 같아 문의드립니다. 요즘 최저임금 상승으로 인한 부담으로 상가 입주자 현황(공실 업소가 많이 발생)이 매우 안좋아서 직원 축소 문제가 많이 발생되고 있어 여러가지로 답답한 마음입니다. 바쁘시지만 답변 부탁드립니다.수고하세요.
#
# 답변자 : 콜센터
#
# 답변내용 : 근로복지공단 콜센터입니다.먼저 우리 공단 홈페이지에 대한 고객님의 관심에 감사드립니다. 질문하신 내용에 대한 상세설명을 위해 2018년 9월 4일 오후 3시 45분경 고객님께 전화 드려, 최저임금 인상에 따라 2018년도 한시적으로 지원하는 일자리 안정자금 사업과 관련하여 현재 지원연장 등 세부 시행지침이 정해진 바 없기에 내년 지원을 가정하여 달리 답을 드릴 수 없음을 설명 드렸으며, 그 내용으로 답변을 갈음하겠습니다. 보다 나은 서비스 제공을 위해 항상 노력하겠습니다. 오늘도 행복한 하루 보내시길 바랍니다.  ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료 등으로 사용할 수 없으니 참고하시기 바랍니다.
#
#
# ...
#
# 글번호 : 155546
# 공개여부 : 공개
# 제목 : 일자리안정자금 지원문의
# ...

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver

from urllib.request import urlopen

from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--headless")

  
    
def scroll_down(driver):
    #driver.execute_script("window.scrollTo(500,document.body.scrollHeight);")
    driver.execute_script("window.scrollBy(0,3000);") # 한페이지 20개씩 출력값
    time.sleep(2)

driver = webdriver.Chrome("C:/temp/chromedriver_240/chromedriver.exe", options= chrome_options)
driver.get('https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20')

url='https://www.kcomwel.or.kr/kcomwel/help/cyber/cyber_list.jsp?page=11&req_tp=20'


for i in range(20,1076,10):
    driver.find_element_by_link_text(str(i)).click()
    time.sleep(1.5)
    driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()
    time.sleep(1.5)  

driver.find_element_by_link_text(str(1078)).click()
#   driver.find_element_by_link_text(str(951)).click()


번호 = []
공개여부 = []
제목=[]
등록일 = []
작성자=[]
처리지사=[]
진행현황 = []

내용 = []

답변자 = []
답변내용 = []

#driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(4) ).click()
#time.sleep(3)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(14) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(18) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(22) ).click()
# time.sleep(10)
# driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(26) ).click()
# time.sleep(10)


for n in range(1078,1123):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    #voice = soup.select('#is-cont > div.cont-box > div > div > div.jwxe_root.jwxe_board.pras-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr')
    voice = soup.select('#contents > table > tbody > tr')                     
    
    for i in range(len(voice)):
        no = voice[i].find_all('td')[0].get_text().strip() # 번호
        public = voice[i].find('img').get('alt').strip() # 공개여부 
        title = voice[i].find_all('td')[2].get_text().strip() # 제목
        date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
        writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
        answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
        status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
#         if no=='302':
#             print(no,'글은 삭제되었습니다.')
#             content='삭제된 글'
#             continue
        i

        #scroll_down(driver)
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.tb-scroll.jwxe_root.jwxe_board.common-board.ko > div.mscroll > table > tbody > tr:nth-child(%s) > td.tdleft > a'%(i+1)).click()
        

        
        
         
        if public=='공개' and status=='처리완료':
            
            driver.find_element_by_css_selector('''#contents > table > tbody > tr:nth-child(%s) > td.td01 > a'''%(i+1)).click()
#             try:
#                 driver.find_element_by_xpath('''//*[@id="is-cont"]/div[2]/div/div/div[3]/div[2]/div[2]/table/tbody/tr[%s]/td[3]/a'''%(code)).click()
#             except :
#                 continue
            
            time.sleep(2)
            try:
                soup2 = BeautifulSoup(driver.page_source, 'html.parser')#'html.parser')
    
                #content= soup2.find('#contents > table.view02 > tbody > tr:nth-child(1) > td > p').get_text().strip()
                content = soup2.find(id="contents").find('table').find('p').text
                #answer = soup2.find('#contents > table.viewAn > tbody > tr:nth-child(2) > td.td02 > div').get_text().strip()
                answer = soup2.find(id='contents').find('table',{'class':'viewAn'}).find('tbody').find('div').text


            except IndexError:
                continue
            
            except AttributeError:
                print("답글이 작성되지 않았습니다.")
                driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
                continue
    #         except NoSuchElementException:

    #             print(no,"번 글은 삭제된 페이지입니다.")

    #         except TimeoutException:
    #             continue

            else:
                #content = content.replace('\xa0', ' ')
                #answer = answer.replace('')
                
                content = content.replace('\n', ' ')
                answer = answer.replace('\n', ' ')
                answer = answer.replace('\xa0', ' ')
            time.sleep(2)
            driver.find_element_by_xpath('//*[@id="contents"]/div/a/img').click()
        
        else:
            continue
        
        
        #driver.find_element_by_css_selector('#is-cont > div.cont-box > div > div > div > div > div.jwxe_root.jwxe_board.free-board.ko > div.btn_wrap.al_right > a:nth-child(1)').click()
        
        
        

#         if status == '제출':
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[2]/a[1]').click()                                     
#         else:
#             driver.find_element_by_xpath('//*[@id="is-cont"]/div[2]/div/div/div[7]/div[3]/a[1]').click()
        



#         no = voice[i].find_all('td')[0].get_text().strip() # 번호
#         public = voice[i].find_all('td')[1].find('img').get('alt').strip() # 공개여부 
#         title = voice[i].find_all('td')[2].get_text().strip() # 제목
#         date_time = voice[i].find_all('td')[3].get_text().strip() # 등록일        
#         writer = voice[i].find_all('td')[4].get_text().strip() # 작성자
#         answer_name = voice[i].find_all('td')[5].get_text().strip() # 처리지사
#         status = voice[i].find_all('td')[6].get_text().strip()# 답변자
        
        번호.append(no)
        공개여부.append(public)
        제목.append(title)
        등록일.append(date_time)
        작성자.append(writer)
        처리지사.append(answer_name)
        진행현황.append(status)
        내용.append(content)
        


        답변자.append(answer_name)
        답변내용.append(answer)
        #링크.append(str(urlopen(url,a)) )
        
        
        print("=================================================================================================")
        print()
        print('글번호 :',no)
        print("공개여부 :",public)
        print("제목 :",title)
        print("등록일 :", date_time)
        print('작성자 :', writer)       
        print("처리지사 :", answer_name)
        print("진행현황:", status)
        print("내용 :", content)
        print()
        print("답변자 :", answer_name)
        print()
        print("답변내용 :",answer)
        print()
        
        #print(링크)
        print()
        print("=================================================================================================")
        

        time.sleep(2)
        
    print('-----------------------------', n, '페이지 완료 ---------------------------------------------\n')
    #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
    #driver.find_elememnt_by_xpath("//*[@id="contents"]/ul/li[12]/a").click()
    if n % 10 !=0:
        driver.find_element_by_link_text(str(n+1)).click()
        time.sleep(2)
    elif n% 10 == 0:
        #driver.find_element_by_xpath('//a[.//span[text()=%s]]'% str(n+1) ).click()
        driver.find_element_by_xpath('//*[@id="contents"]/ul/li[13]/a').click()                         
    time.sleep(3)
# Out:
# ...
#
# 글번호 : 153039
# 공개여부 : 공개
# 제목 : 일자리 안정자금 수령월
# 등록일 : 2018-03-26
# 작성자 : 하**
# 처리지사 : 콜센터
# 진행현황: 처리완료
# 내용 : 안녕하세요 수고많으십니다. 저희는 이번에 일자리 안정자금신청한 보험사무대행기관입니다.  문의 사항 1. 이번 일자리 안정자금신청에서 신청서에 지급월을 2월로 신청하였습니다  2. 신청지급월을 잘못신청한것같아서 1월로 변경신청서를 제출하였습니다  3. 근로복지공단에서 연락을 방금받았는데 일자리 안정자금 수령월이 2월에서1월로 변경이  안된어서 1월부터 수령이 안된다는 연락을 받았습니다.  일자리 안정자금의 취지가 최저임금인상으로 인항 영세사업자의 부담을 완화하자는 취지인데  서류가 잘못접수되었다는 이유만으로 일자리 안정자금의 취지와 상반되게 일처리가 되는지  궁금합니다  서류작성이 잘못되었다는 이유만으로 그리고 변경신청서를 제출하였는데 왜 일자리   안정자금신청 수령이 1월부터 안되는지 궁금합니다  빠른 답변부탁드립니다.
#
# 답변자 : 콜센터
#
# ...

# %%
import pandas as pd

df3 = pd.DataFrame(columns= ['글번호','공개여부','제목','등록일','작성자','처리지사','진행현황', '내용', '답변자', '답변내용'])





df3['글번호'] = 번호
df3['공개여부']= 공개여부
df3['제목'] = 제목
df3['등록일'] = 등록일
df3['작성자'] = 작성자
df3['처리지사'] = 처리지사
df3['진행현황'] = 진행현황
df3['내용'] = 내용
df3['답변자'] = 답변자
df3['답변내용'] = 답변내용

df3   
    
    

#         번호.append(no)
#         제목.append(title)
#         작성자.append(writer)
#         등록일.append(date_time)
#         진행현황.append(status)
#         내용.append(content)
# Out:
#         글번호 공개여부                       제목         등록일  작성자 처리지사  진행현황  \
# 0    155578   공개        내년 일자리 안정자금 지급 관련  2018-09-04  임**  콜센터  처리완료
# 1    155546   공개             일자리안정자금 지원문의  2018-08-31  이**  콜센터  처리완료
# 2    155545   공개          아르바이트생 일자리 안정자금  2018-08-31  김**  콜센터  처리완료
# 3    155483   공개  주40시간 미만 노동자 지원금액 문의...  2018-08-28  표**  콜센터  처리완료
# 4    155437   공개  일자리안정자금과 피보험자격 문의 입니...  2018-08-24  이**  콜센터  처리완료
# ..      ...  ...                      ...         ...  ...  ...   ...
# 131  153100   공개         일자리 안정자금 신청서류 문의  2018-03-29  양**  콜센터  처리완료
# 132  153088   공개  경비청소 용역업체 일자리안정자금 신청...  2018-03-28  조**  콜센터  처리완료
# 133  153081   공개  일자리안정자금이 확정된후에 지급받으며...  2018-03-28  송**  콜센터  처리완료
# 134  153063   공개  2018년 1월말 퇴사직원, 2월 지...  2018-03-27  김**  콜센터  처리완료
# 135  153050   공개  단시간근로자 고용보험적용  관련 질의...  2018-03-27  박**  콜센터  처리완료
#
#                                                     내용  답변자  \
# 0    상가 건물 관리사무소 경비 위생원 직원에 대하여 현재 일자리 안정자금을 지급받고 있...  콜센터
# ...

# %%
import pandas as pd

df2 = pd.DataFrame(columns= ['글번호','공개여부','제목','등록일','작성자','처리지사','진행현황', '내용', '답변자', '답변내용'])





df2['글번호'] = 번호
df2['공개여부']= 공개여부
df2['제목'] = 제목
df2['등록일'] = 등록일
df2['작성자'] = 작성자
df2['처리지사'] = 처리지사
df2['진행현황'] = 진행현황
df2['내용'] = 내용
df2['답변자'] = 답변자
df2['답변내용'] = 답변내용

df2   
    
    
df2.to_csv("사이버 고객상담 일자리안정자금_1078부터 끝까지(utf-8-sig)_result.csv", encoding= 'utf-8-sig')
#         번호.append(no)
#         제목.append(title)
#         작성자.append(writer)
#         등록일.append(date_time)
#         진행현황.append(status)
#         내용.append(content)
# Out:
#         글번호 공개여부                       제목         등록일  작성자 처리지사  진행현황  \
# 0    155578   공개        내년 일자리 안정자금 지급 관련  2018-09-04  임**  콜센터  처리완료
# 1    155546   공개             일자리안정자금 지원문의  2018-08-31  이**  콜센터  처리완료
# 2    155545   공개          아르바이트생 일자리 안정자금  2018-08-31  김**  콜센터  처리완료
# 3    155483   공개  주40시간 미만 노동자 지원금액 문의...  2018-08-28  표**  콜센터  처리완료
# 4    155437   공개  일자리안정자금과 피보험자격 문의 입니...  2018-08-24  이**  콜센터  처리완료
# ..      ...  ...                      ...         ...  ...  ...   ...
# 131  153100   공개         일자리 안정자금 신청서류 문의  2018-03-29  양**  콜센터  처리완료
# 132  153088   공개  경비청소 용역업체 일자리안정자금 신청...  2018-03-28  조**  콜센터  처리완료
# 133  153081   공개  일자리안정자금이 확정된후에 지급받으며...  2018-03-28  송**  콜센터  처리완료
# 134  153063   공개  2018년 1월말 퇴사직원, 2월 지...  2018-03-27  김**  콜센터  처리완료
# 135  153050   공개  단시간근로자 고용보험적용  관련 질의...  2018-03-27  박**  콜센터  처리완료
#
#                                                     내용  답변자  \
# 0    상가 건물 관리사무소 경비 위생원 직원에 대하여 현재 일자리 안정자금을 지급받고 있...  콜센터
# ...

# %%
df3.to_csv("사이버 고객상담 일자리안정자금_1078부터 끝까지(utf-8-sig)_result.csv", encoding= 'utf-8-sig')

# %%
df3.to_csv("사이버 고객상담 일자리안정자금_1078부터 끝까지(cp949)_result.csv", encoding= 'cp949')
# Out:
# -----------------------------------------------
# UnicodeEncodeErrorTraceback (most recent call last)
# <ipython-input-8-2c1502a6b94a> in <module>
# ----> 1 df3.to_csv("사이버 고객상담 일자리안정자금_1078부터 끝까지(cp949)_result.csv", encoding= 'cp949')
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# ~\.conda\envs\cslee3.7\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     326                 break
#     327
# ...
